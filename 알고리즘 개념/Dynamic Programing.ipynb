# %% [markdown]
# # Dynamic Programing
#
# 입력 크기가 작은 부분 문제들을 먼저 해결
# 작은 문제의 해를 활용하여 보다 큰 크기의 부분 문제를 해결하는 알고리즘
# 상향식 접근법
# Memorization 기법을 사용함

# %% [markdown]
# ### 피보나치 수열
# <img src="https://www.fun-coding.org/00_Images/Fibonacci.png" />

# %%
#재귀 함수로 구현
def fibo(num):
    if num <=1:
        return num
    return fibo(num - 1) + fibo(num - 2)

# %%
fibo(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a9bc4b4d9fba> in <module>
# ----> 1 fibo(1000)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
# ...
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# <ipython-input-1-89e7884a1aba> in fibo(num)
#       3     if num <=1:
#       4         return num
# ----> 5     return fibo(num - 1) + fibo(num - 2)
#
# KeyboardInterrupt:

# %%
# 다이나믹 프로그래밍으로 구현
def fibo_dp(num):
    cache = [0 for index in range(num + 1)]
    cache[1] = 1
    for index in range(2, len(cache)):
        cache[index] = cache[index - 1] + cache[index - 2]
    return cache[-1]

# %%
fibo_dp(1000)
